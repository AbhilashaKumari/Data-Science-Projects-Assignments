# %% [markdown]
# <img src="http://www.digitalvidya.com/wp-content/uploads/2013/05/logoa5-300x95.png">

# %% [markdown]
# ## Data Analysis using Python Assignment Week 7
# ### Digital Vidya Copyright

# %% [markdown]
# We get NSE stocks data using package nsepy. You will have to first install nsepy using the command pip install nsepy.
#
# Use function get_history, it fetches the price history of stocks/indices/derivatives and returns a pandas dataframe.
#
# We are going to use data of 'INFY', 'HDFC', 'RELIANCE', 'WIPRO'
#
# We have created the dataframes hdfc, infy, wipro and reliance.
#
# We will use the dataframes created above to create plots.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nsepy import get_history
import datetime as dt
# %matplotlib inline

start = dt.datetime(2015, 1, 1)

end = dt.datetime.today()

infy = get_history(symbol='INFY', start = start, end = end)
infy.index = pd.to_datetime(infy.index)
infy

hdfc = get_history(symbol='HDFC', start = start, end = end)
hdfc.index = pd.to_datetime(hdfc.index)
hdfc

reliance = get_history(symbol='RELIANCE', start = start, end = end)
reliance.index = pd.to_datetime(reliance.index)
reliance

wipro = get_history(symbol='WIPRO', start = start, end = end)
wipro.index = pd.to_datetime(wipro.index)
wipro
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01  WIPRO     EQ      555.20  552.55  554.40  550.50  552.25  552.40
# 2015-01-02  WIPRO     EQ      552.40  553.40  560.25  553.00  558.90  557.30
# 2015-01-05  WIPRO     EQ      557.30  557.05  565.00  555.50  558.55  558.30
# 2015-01-06  WIPRO     EQ      558.30  555.00  556.40  542.10  545.50  545.25
# 2015-01-07  WIPRO     EQ      545.25  543.20  545.00  538.35  541.50  541.10
# 2015-01-08  WIPRO     EQ      541.10  556.15  558.90  543.20  545.00  545.00
# 2015-01-09  WIPRO     EQ      545.00  549.20  560.00  543.25  552.50  553.50
# 2015-01-12  WIPRO     EQ      553.50  550.00  559.00  547.70  556.00  556.05
# 2015-01-13  WIPRO     EQ      556.05  557.10  566.70  555.00  565.70  563.50
# 2015-01-14  WIPRO     EQ      563.50  566.00  569.50  550.00  550.15  551.95
# 2015-01-15  WIPRO     EQ      551.95  560.00  564.00  551.25  561.90  559.50
# 2015-01-16  WIPRO     EQ      559.50  560.80  563.40  552.90  555.90  555.05
# 2015-01-19  WIPRO     EQ      555.05  591.10  598.50  582.35  584.45  584.20
# 2015-01-20  WIPRO     EQ      584.20  586.10  594.00  582.90  588.80  590.40
# 2015-01-21  WIPRO     EQ      590.40  589.60  595.00  576.65  592.00  588.70
# 2015-01-22  WIPRO     EQ      588.70  590.00  597.70  584.70  592.95  594.55
# 2015-01-23  WIPRO     EQ      594.55  599.20  604.00  590.25  599.75  601.80
# 2015-01-27  WIPRO     EQ      601.80  602.40  605.75  595.00  595.50  598.55
# 2015-01-28  WIPRO     EQ      598.55  596.00  612.00  595.75  611.55  607.25
# 2015-01-29  WIPRO     EQ      607.25  608.00  614.50  599.80  603.00  602.70
# 2015-01-30  WIPRO     EQ      602.70  606.90  610.05  597.15  606.30  606.55
# 2015-02-02  WIPRO     EQ      606.55  612.00  627.70  609.00  626.70  625.10
# 2015-02-03  WIPRO     EQ      625.10  624.00  628.05  617.75  620.30  621.55
# 2015-02-04  WIPRO     EQ      621.55  623.20  629.90  616.25  619.10  619.20
# 2019-03-05  368.34  13515990  4.978464e+14  117320             7757751
# 2019-03-06  280.68  21507060  6.036503e+14  151205             5764553
# 2019-03-07  272.27   8100134  2.205385e+14  104901             1992069
# 2019-03-08  259.27  27344869  7.089839e+14  151590             3108089
# 2019-03-11  259.34   7354227  1.907239e+14   67494             3360318
# 2019-03-12  262.06   6290354  1.648448e+14   57551             3841453
# 2019-03-13  260.09   7219723  1.877806e+14   83551             3419052
# 2019-03-14  256.49   4489473  1.151489e+14   99216             2138877
# 2019-03-15  262.23   8720097  2.286709e+14  105967             5120638
# 2019-03-18  259.39   5748614  1.491121e+14   68397             2587654
# 2019-03-19  256.44   5051847  1.295495e+14   52534             2726694
#
#             %Deliverble
# Date
# 2015-01-01       0.3685
# 2015-01-02       0.5385
# 2015-01-05       0.5517
# 2015-01-06       0.7608
# 2015-01-07       0.6264
# 2015-01-08       0.5989
# 2015-01-09       0.6117
# 2015-01-12       0.5463
# 2015-01-13       0.5820
# 2015-01-14       0.6314
# 2015-01-15       0.6754
# 2015-01-16       0.5735
# 2015-01-19       0.4385
# 2015-01-20       0.6303
# 2015-01-21       0.6521
# 2015-01-22       0.7492
# 2015-01-23       0.6469
# 2015-01-27       0.7192
# 2015-01-28       0.7968
# 2015-01-29       0.6734
# 2015-01-30       0.6328
# 2015-02-02       0.5925
# 2015-02-03       0.5535
# 2015-02-04       0.6546
# 2015-02-05       0.4895
# 2015-02-06       0.4767
# 2015-02-09       0.5658
# 2015-02-10       0.7609
# 2015-02-11       0.7894
# 2015-02-12       0.5918
# ...                 ...
# 2019-02-05       0.3455
# 2019-02-06       0.3410
# 2019-02-07       0.4125
# 2019-02-08       0.4160
# 2019-02-11       0.4120
# 2019-02-12       0.4902
# 2019-02-13       0.3962
# 2019-02-14       0.5917
# 2019-02-15       0.5696
# 2019-02-18       0.4054
# 2019-02-19       0.2719
# 2019-02-20       0.2997
# 2019-02-21       0.3590
# 2019-02-22       0.4134
# 2019-02-25       0.3252
# 2019-02-26       0.3552
# 2019-02-27       0.3293
# 2019-02-28       0.4520
# 2019-03-01       0.4709
# 2019-03-05       0.5740
# 2019-03-06       0.2680
# 2019-03-07       0.2459
# 2019-03-08       0.1137
# 2019-03-11       0.4569
# 2019-03-12       0.6107
# 2019-03-13       0.4736
# 2019-03-14       0.4764
# 2019-03-15       0.5872
# 2019-03-18       0.4501
# 2019-03-19       0.5397
#
# [1044 rows x 14 columns]

# %% [markdown]
# #### Answer the following questions. Do remember to add appropriate title to the graphs.

# %% [markdown]
# #### 1. Use the dataframe open_prices created below to plot a line graph showing each of the four stocks price. Set the figure size to 15,6 for better visualization and add grids. The plot will have four lines depicting each stock and a legend.

# %%
hdfc_year=hdfc[hdfc.index.year.isin([2015,2016,2017])]
open_hdfc=hdfc_year.groupby(hdfc_year.index.year)['Open'].mean()

wipro_year=wipro[wipro.index.year.isin([2015,2016,2017])] 
open_wipro=wipro_year.groupby(wipro_year.index.year)['Open'].mean()

reliance_year=reliance[reliance.index.year.isin([2015,2016,2017])]
open_reliance=reliance_year.groupby(reliance_year.index.year)['Open'].mean()

infy_year=infy[infy.index.year.isin([2015,2016,2017])]
open_infy=infy_year.groupby(infy_year.index.year)['Open'].mean()

x=[open_hdfc,open_wipro,open_reliance,open_infy]
 
open_prices=pd.concat(x,axis=1)
open_prices.plot(figsize = (15,6), grid = True)
plt.legend(labels=['open_hdfc','open_wipro','open_reliance','open_infy'])

# %% [markdown]
# #### 2. Use the dataframe open_prices created in qn 1 to create open_yearly with mean open prices every year. Create a bar chart with stock name on X-axis and price on Y-axis. The resulting plot will have multiple bar plot comparing price of each stock for 2015, 2016 and 2017. The legend should specify which colored bar represents which year for each stock.

# %%
open_prices=pd.concat(x,axis=1)
open_prices.plot.bar()
 
plt.legend(labels=['open_hdfc','open_wipro','open_reliance','open_infy'])

# %% [markdown]
# #### 3. Plot 4 different line plots for the 4 companies in dataframe open_prices. Year would be on X-axis, stock price on Y axis, you will need (2,2) plot. Set figure size to 10, 8 and share X-axis for better visualization.

# %%
open_prices.plot(subplots=True, layout=(2,2), figsize=(10,8), sharex=True)
plt.ylabel("Stock Price")
# Out:
# Text(0, 0.5, 'Stock Price')

# %% [markdown]
# **4. Get the stock prices for TCS for the same time period and plot a line graph with two lines representing daily high and low prices respectively.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nsepy import get_history
import datetime as dt
# %matplotlib inline

start = dt.datetime(2015, 1, 1)

end = dt.datetime.today()

TCS= get_history(symbol='TCS', start = start, end = end)
TCS.index = pd.to_datetime(TCS.index)
TCS
TCS = TCS[['High', 'Low']]
TCS.plot(kind = 'line', figsize = (10, 8), title = 'Stock Prices', grid = True, legend = True, fontsize='xx-large')

# %% [markdown]
# #### 5. Create 3 pie charts from the open_prices dataframe, each representing % mean prices of stocks per year. You should get three charts for year 2015, 2016 and 2017 respectively. Try the parameter layout = (2,2) to get 2 plots on each row.

# %%
open_prices.plot(kind='pie', subplots= True, layout=(2,2), startangle=90, autopct='%1.1f%%')
plt.legend(labels=['hdfc_mean','wipro_mean','reliance_mean','infy_mean'])

# %%
open_prices1=open_prices[open_prices.index.year.isin([2015])]
hdfc_mean=open_prices1.open_hdfc.index.year.mean()
wipro_mean=open_prices1.open_wipro.mean()
reliance_mean=open_prices1.open_reliance.mean()
infy_mean=open_prices1.open_infy.mean()
mean=[hdfc_mean, wipro_mean, reliance_mean, infy_mean]
stocks=['hdfc','wipro','reliance','infy']
plt.pie(mean,labels=stocks, startangle=90, autopct='%1.1f%%')

# %%
open_prices1=open_prices[open_prices.index.year.isin([2016])]
hdfc_mean=open_prices1.open_hdfc.mean()
wipro_mean=open_prices1.open_wipro.mean()
reliance_mean=open_prices1.open_reliance.mean()
infy_mean=open_prices1.open_infy.mean()
mean=[hdfc_mean, wipro_mean, reliance_mean, infy_mean]
stocks=['hdfc','wipro','reliance','infy']
plt.pie(mean,labels=stocks, subplots= True, layout=(2,2),startangle=90, autopct='%1.1f%%')

# %%
open_prices1=open_prices[open_prices.index.year.isin([2017])]
hdfc_mean=open_prices1.open_hdfc.mean()
wipro_mean=open_prices1.open_wipro.mean()
reliance_mean=open_prices1.open_reliance.mean()
infy_mean=open_prices1.open_infy.mean()
mean=[hdfc_mean, wipro_mean, reliance_mean, infy_mean]
stocks=['hdfc','wipro','reliance','infy']
plt.pie(mean,labels=stocks, startangle=90, autopct='%1.1f%%')
